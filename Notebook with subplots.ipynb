# %% [markdown]
# Taken from https://python-course.eu/numerical-programming/creating-subplots-in-matplotlib.php

# %% [markdown]
# We use the subplots function of matplotlib...

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(6, 4))

fig, ax = plt.subplots(2, 
           sharex='col', sharey='row')
x = np.linspace(0, 2*np.pi, 400)
y = np.sin(x**2) + np.cos(x)
derivative = 2 * x * np.cos(x**2) - np.sin(x)
ax[0].plot(x, y)
ax[0].set(title='The function')
ax[1].plot(x, derivative)
ax[1].set(title="It's derivative")
plt.show()

# %%
import matplotlib.pyplot as plt

# Using Numpy to create an array X
X = np.arange(0, np.pi*2, 0.05)
  
# Assign variables to the y axis part of the curve
y = np.sin(X)
z = np.cos(X)
  
# Plotting both the curves simultaneously
plt.plot(X, y, color='r', label='sin')
plt.plot(X, z, color='g', label='cos')
  
# Naming the x-axis, y-axis and the whole graph
plt.xlabel("Angle")
plt.ylabel("Magnitude")
plt.title("Sine and Cosine functions")
  
# Adding legend, which helps us recognize the curve according to it's color
plt.legend()
  
# To load the display window
plt.show()
